# %%
import pandas as pd
import numpy as np
import scipy as sc

from statsmodels.sandbox.stats.multicomp import multipletests

# %% [markdown]
# ## Data: gene expression in white blood cells
#
# We have data from the analysis of gene expression (level of activity of a gene) in white blood cells of children with severe therapy-resistant asthma, and healthy controls. Results provide insight into the molecular pathogenesis of  asthma. Data is collected with DNA microarrays: https://en.wikipedia.org/wiki/DNA_microarray
#
# We would like to understand which genes have different average activity levels between healthy and diseased groups.
#
# Data source: http://www.ncbi.nlm.nih.gov/sites/GDSbrowser?acc=GDS4896

# %%
expression = pd.read_csv('expression.csv')

# %%
expression.head()
# Out:
#     ID_REF IDENTIFIER  Healthy control  Healthy control.1  Healthy control.2  \
# 0  7933640       A1CF          4.24505            4.44464            4.36671
# 1  7960947        A2M          4.79868            4.76833            4.66414
# 2  7953775      A2ML1          4.79161            5.12633            4.93860
# 3  8076497     A4GALT          5.79783            5.93942            5.82935
# 4  8090955      A4GNT          3.79685            4.00154            3.83103
#
#    Healthy control.3  Healthy control.4  Healthy control.5  Healthy control.6  \
# 0            4.33497            4.45717            4.37972            4.40154
# 1            4.80272            4.85779            4.77622            4.92634
# 2            4.74597            4.91789            4.74453            5.23725
# 3            5.91139            5.60195            5.68317            6.01254
# 4            3.91021            3.81930            3.86203            3.97020
#
#    Healthy control.7  ...  Severe asthma.8  Severe asthma.9  Severe asthma.10  \
# 0            4.40521  ...          4.59426          4.56012           4.60672
# 1            4.88576  ...          5.01994          5.15406           5.13639
# 2            4.83903  ...          5.22915          5.11131           5.33257
# 3            5.84921  ...          6.16251          6.21829           6.06835
# 4            3.84166  ...          4.17925          3.99698           4.09657
#
#    Severe asthma.11  Severe asthma.12  Severe asthma.13  Severe asthma.14  \
# 0           4.43026           4.55835           4.25656           4.52559
# 1           4.99052           4.88454           4.68904           4.85329
# 2           5.05544           4.96971           4.96505           4.76993
# 3           5.80154           6.06533           5.79955           5.94065
# 4           4.00232           3.70843           3.79290           4.31364
#
#    Severe asthma.15  Severe asthma.16  \
# 0           4.42976           4.37098
# 1           5.05764           5.48561
# 2           5.04489           4.70002
# 3           6.08192           5.86693
# 4           3.94925           3.62481
#
#                                   Gene title
# 0             APOBEC1 complementation factor
# 1                      alpha-2-macroglobulin
# 2               alpha-2-macroglobulin-like 1
# 3            alpha 1,4-galactosyltransferase
# 4  alpha-1,4-N-acetylglucosaminyltransferase
#
# [5 rows x 38 columns]

# %%
print("Number of genes in the study:", expression.shape[0])
healthy = [col for col in expression if col.startswith('Healthy')]
print("Number of healthy controls:", len(healthy))
asthma = [col for col in expression if col.startswith('Severe')]
print("Number of children with severe asthma:", len(asthma))
# Out:
# Number of genes in the study: 21465
# Number of healthy controls: 18
# Number of children with severe asthma: 17

# %%
expression['mean_healthy'] = expression[healthy].apply(np.mean, axis=1)
expression['mean_asthma'] = expression[asthma].apply(np.mean, axis=1)

# %% [markdown]
# For each gene, we are going to compare average expression levels between healthy children and children with severe asthma using t test:

# %%
def compare_groups(row):
    p = sc.stats.ttest_ind(row[healthy], row[asthma], equal_var = False).pvalue
    return p

expression['p'] = expression.apply(compare_groups, axis=1)

# %% [markdown]
# How many genes have significantly different average expression levels – without accounting for multiple hypotheses testing?

# %%
print('Number of significant differences, no correction for multiplicity:', sum(expression.p <= 0.05))
# Out:
# Number of significant differences, no correction for multiplicity: 2772

# %% [markdown]
# ## Holm's method

# %% [markdown]
# Let's correct for multiple hypothesis testing using Holm's method to control FWER:

# %%
_, expression['p_adjusted_holm'], _, _ = multipletests(expression.p, alpha = 0.05, method = 'holm') 
print('Number of significant differences with FWER <= 0.05:', sum(expression.p_adjusted_holm <= 0.05))
expression[expression.p_adjusted_holm <= 0.05][['IDENTIFIER', 'Gene title', 'mean_healthy', 'mean_asthma', 
                                                'p', 'p_adjusted_holm']]
# Out:
# Number of significant differences with FWER <= 0.05: 9
#        IDENTIFIER                                         Gene title  \
# 431    AGPAT4-IT1  AGPAT4 intronic transcript 1 (non-protein coding)
# 2865          CD4                                       CD4 molecule
# 7128        GPR21                      G protein-coupled receptor 21
# 7144        GPR52                      G protein-coupled receptor 52
# 10186         LPP  LIM domain containing preferred translocation ...
# 12641        OCR1                   ovarian cancer-related protein 1
# 17245    SND1-IT1    SND1 intronic transcript 1 (non-protein coding)
# 18225       SYNE2     spectrin repeat containing, nuclear envelope 2
# 20763        ZEB2               zinc finger E-box binding homeobox 2
#
#        mean_healthy  mean_asthma             p  p_adjusted_holm
# 431        5.591794     5.906907  5.504217e-07         0.011812
# 2865      10.332761     9.994222  2.169653e-06         0.046554
# 7128       5.907257     6.853551  3.304167e-08         0.000709
# 7144       6.284526     7.202818  1.456452e-08         0.000313
# 10186      8.943248     9.276649  1.816116e-07         0.003897
# 12641      7.043893     8.379184  9.935442e-08         0.002132
# 17245      5.543953     6.252731  3.057326e-08         0.000656
# 18225      8.603884     9.020421  1.323281e-06         0.028395
# 20763      6.341786     7.358729  3.958029e-08         0.000849

# %% [markdown]
# Just for comparison – here's what we would get using Bonferroni's correction:

# %%
_, expression['p_adjusted_bonf'], _, _ = multipletests(expression.p, alpha = 0.05, method = 'bonferroni') 
expression[expression.p_adjusted_bonf <= 0.05][['IDENTIFIER', 'Gene title', 'mean_healthy', 'mean_asthma', 
                                                'p', 'p_adjusted_bonf']]
# Out:
#        IDENTIFIER                                         Gene title  \
# 431    AGPAT4-IT1  AGPAT4 intronic transcript 1 (non-protein coding)
# 2865          CD4                                       CD4 molecule
# 7128        GPR21                      G protein-coupled receptor 21
# 7144        GPR52                      G protein-coupled receptor 52
# 10186         LPP  LIM domain containing preferred translocation ...
# 12641        OCR1                   ovarian cancer-related protein 1
# 17245    SND1-IT1    SND1 intronic transcript 1 (non-protein coding)
# 18225       SYNE2     spectrin repeat containing, nuclear envelope 2
# 20763        ZEB2               zinc finger E-box binding homeobox 2
#
#        mean_healthy  mean_asthma             p  p_adjusted_bonf
# 431        5.591794     5.906907  5.504217e-07         0.011815
# 2865      10.332761     9.994222  2.169653e-06         0.046572
# 7128       5.907257     6.853551  3.304167e-08         0.000709
# 7144       6.284526     7.202818  1.456452e-08         0.000313
# 10186      8.943248     9.276649  1.816116e-07         0.003898
# 12641      7.043893     8.379184  9.935442e-08         0.002133
# 17245      5.543953     6.252731  3.057326e-08         0.000656
# 18225      8.603884     9.020421  1.323281e-06         0.028404
# 20763      6.341786     7.358729  3.958029e-08         0.000850

# %% [markdown]
# It's the same 9 genes! We test so many hypotheses here that even the more powerful Holm's method is not able to reject more than Bonferroni's – controlling FWER is probably too strict.

# %% [markdown]
# ## Benjamini-Hochberg's method
# DNA microarrays are an exploratory tool – they are used to generate scientific hypotheses that later could be tested with more precise instruments. It might make sense to allow some type I errors to be able to have higher power.
#
# Let's correct for multiple hypothesis testing using Benjamini-Hochberg's method to control FDR (as they usually do in microarray analysis):

# %%
_, expression['p_adjusted_bh'], _, _ = multipletests(expression.p, alpha = 0.05, method = 'fdr_bh') 
print('Number of significant differences with FDR <= 0.05:', sum(expression.p_adjusted_bh <= 0.05))
with pd.option_context('display.max_rows', None):
    display(expression[expression.p_adjusted_bh <= 0.05][['IDENTIFIER', 'Gene title', 'mean_healthy', 
                                                          'mean_asthma', 'p', 'p_adjusted_bh']])
# Out:
# Number of significant differences with FDR <= 0.05: 168
#          IDENTIFIER                                         Gene title  \
# 18             AAR2       AAR2 splicing factor homolog (S. cerevisiae)
# 135           ACBD3               acyl-CoA binding domain containing 3
# 261          ADAM20                    ADAM metallopeptidase domain 20
# 315           ADCK2                    aarF domain containing kinase 2
# 431      AGPAT4-IT1  AGPAT4 intronic transcript 1 (non-protein coding)
# 582          ALKBH5              AlkB family member 5, RNA demethylase
# 662         ANGPTL1                                angiopoietin-like 1
# 738         ANKRD36  ankyrin repeat domain 36///ankyrin repeat doma...
# 777      ANP32A-IT1  ANP32A intronic transcript 1 (non-protein coding)
# 854           APH1A                      APH1A gamma secretase subunit
# 1942       C17orf85                chromosome 17 open reading frame 85
# 2104       C22orf34                chromosome 22 open reading frame 34
# 2768           CCNH                                           cyclin H
# 2769           CCNI                                           cyclin I
# 2865            CD4                                       CD4 molecule
# 2868           CD44                 CD44 molecule (Indian blood group)
# 3298         CHRAC1                  chromatin accessibility complex 1
# 3363         CIRH1A         cirrhosis, autosomal recessive 1A (cirhin)
# 3480           CLN8  ceroid-lipofuscinosis, neuronal 8 (epilepsy, p...
# 3515           CMBL  carboxymethylenebutenolidase homolog (Pseudomo...
# 4073        CWF19L2        CWF19-like 2, cell cycle control (S. pombe)
# 4307        DCLRE1B                           DNA cross-link repair 1B
# 4384          DDX49          DEAD (Asp-Glu-Ala-Asp) box polypeptide 49
# 4402           DEDD                   death effector domain containing
# 4476           DEXI                               Dexi homolog (mouse)
# 4776         DPAGT1  dolichyl-phosphate (UDP-N-acetylglucosamine) N...
# 4954         DYRK1A  dual-specificity tyrosine-(Y)-phosphorylation ...
# 5037        EEF1DP3  eukaryotic translation elongation factor 1 del...
# 5071          EFNB2                                          ephrin-B2
# 5101      EHMT1-IT1                        EHMT1 intronic transcript 1
# 5114          EIF2A  eukaryotic translation initiation factor 2A, 6...
# 5374          ERCC2      excision repair cross-complementation group 2
# 5389         ERGIC3                                  ERGIC and golgi 3
# 5546           F8A3  coagulation factor VIII-associated 3///coagula...
# 5617        FAM127A      family with sequence similarity 127, member A
# 5629       FAM133CP  family with sequence similarity 133, member A ...
# 5738        FAM206A  family with sequence similarity 206, member A/...
# 5767        FAM220A      family with sequence similarity 220, member A
# 5992         FBXO18                        F-box protein, helicase, 18
# 6075          FEM1B                       fem-1 homolog b (C. elegans)
# 6201       FLJ11710                   uncharacterized protein FLJ11710
# 6205       FLJ16734                          uncharacterized LOC641928
# 6254       FLJ42393                          uncharacterized LOC401105
# 6274       FLJ46363                           uncharacterized FLJ46363
# 6431           FRYL                                           FRY-like
# 6562          GAFA2                FGF-2 activity-associated protein 2
# 6893          GMEB1  glucocorticoid modulatory element binding prot...
# 7025          GPA33                   glycoprotein A33 (transmembrane)
# 7064           GPN2                                  GPN-loop GTPase 2
# 7128          GPR21                      G protein-coupled receptor 21
# 7144          GPR52                      G protein-coupled receptor 52
# 7313         GTF2E2  general transcription factor IIE, polypeptide ...
# 7369         GUSBP9  glucuronidase, beta pseudogene 9///glucuronida...
# 7374         GUSBP9  glucuronidase, beta pseudogene 9///glucuronida...
# 7455           HAX1                       HCLS1 associated protein X-1
# 7846     HNRNPU-AS1  HNRNPU antisense RNA 1///COX20 cytochrome C ox...
# 8099          IDH3A            isocitrate dehydrogenase 3 (NAD+) alpha
# 8222           IGK@  immunoglobulin kappa locus///immunoglobulin ka...
# 8422         INTS12                      integrator complex subunit 12
# 8502          ISCA2                     iron-sulfur cluster assembly 2
# 9012           KLF4                        Kruppel-like factor 4 (gut)
# 9284          KTI12  KTI12 homolog, chromatin associated (S. cerevi...
# 9339          LARP1       La ribonucleoprotein domain family, member 1
# 9614      LINC00597         long intergenic non-protein coding RNA 597
# 9757   LOC100128175                       uncharacterized LOC100128175
# 9767   LOC100128644                                           LMNE6487
# 9836   LOC100131541                       uncharacterized LOC100131541
# 9848   LOC100132099                                           FRSS1829
# 9864   LOC100133106                                           VCEW9374
# 9994      LOC389607                          uncharacterized LOC389607
# 10104     LOC648987                          uncharacterized LOC648987
# 10186           LPP  LIM domain containing preferred translocation ...
# 10316       LRRFIP1  leucine rich repeat (in FLII) interacting prot...
# 10472         MACF1            microtubule-actin crosslinking factor 1
# 10776          MDM4                                MDM4, p53 regulator
# 11091        MIR197                                       microRNA 197
# 11117      MIR219A2                                    microRNA 219a-2
# 11132         MIR28                                        microRNA 28
# 11176   MIR4435-1HG  MIR4435-1 host gene (non-protein coding)///lon...
# 11240         MKI67                      marker of proliferation Ki-67
# 11984         NCSTN                                          nicastrin
# 12058        NECAP2                     NECAP endocytosis associated 2
# 12091          NET1                neuroepithelial cell transforming 1
# 12124        NFE2L1                 nuclear factor, erythroid 2-like 1
# 12280          NOA1                          nitric oxide associated 1
# 12318      NOTCH2NL                  notch 2 N-terminal like///notch 2
# 12436         NRIP2             nuclear receptor interacting protein 2
# 12641          OCR1                   ovarian cancer-related protein 1
# 12861         OR2W3  olfactory receptor, family 2, subfamily W, mem...
# 13123          ORM2                      orosomucoid 2///orosomucoid 1
# 13261         PAICS  phosphoribosylaminoimidazole carboxylase, phos...
# 13320        PARGP1      poly (ADP-ribose) glycohydrolase pseudogene 1
# 13456          PCNP  PEST proteolytic signal containing nuclear pro...
# 13457          PCNP  PEST proteolytic signal containing nuclear pro...
# 13550          PDK2           pyruvate dehydrogenase kinase, isozyme 2
# 13621         PEX19                   peroxisomal biogenesis factor 19
# 13718          PHF7                               PHD finger protein 7
# 14106       POLDIP2  polymerase (DNA-directed), delta interacting p...
# 14110         POLE3  polymerase (DNA directed), epsilon 3, accessor...
# 14224        PP7080  uncharacterized LOC25845///exocyst complex com...
# 14258       PPIAL4B  peptidylprolyl isomerase A (cyclophilin A)-lik...
# 14554         PRPS2          phosphoribosyl pyrophosphate synthetase 2
# 14698        PSMD11  proteasome (prosome, macropain) 26S subunit, n...
# 14735         PTBP2             polypyrimidine tract binding protein 2
# 14750        PTDSS1                      phosphatidylserine synthase 1
# 14847         PTTG2                     pituitary tumor-transforming 2
# 14917        QRICH2                                   glutamine rich 2
# 15094       RAPGEF1     Rap guanine nucleotide exchange factor (GEF) 1
# 15303          RER1  retention in endoplasmic reticulum sorting rec...
# 15392          RGS7                 regulator of G-protein signaling 7
# 15611         RNF26                             ring finger protein 26
# 15641       RNU105B                         RNA, U105B small nucleolar
# 15654        RNU4-2                            RNA, U4 small nuclear 2
# 15831         RPRD2  regulation of nuclear pre-mRNA domain containi...
# 15920         RRAGA                          Ras-related GTP binding A
# 15927         RREB1           ras responsive element binding protein 1
# 16520         SGPP2              sphingosine-1-phosphate phosphatase 2
# 16612         SIAH1                 siah E3 ubiquitin protein ligase 1
# 16640         SIN3A       SIN3 transcription regulator family member A
# 16750       SLC18B1    solute carrier family 18, subfamily B, member 1
# 16916       SLC35C1  solute carrier family 35 (GDP-fucose transport...
# 16979       SLC43A3                 solute carrier family 43, member 3
# 17168        SMG1P3  SMG1 pseudogene 3///bolA family member 2B///SM...
# 17174        SMG1P3  SMG1 pseudogene 3///SMG1 pseudogene 1///SMG1 p...
# 17177        SMG1P7  SMG1 pseudogene 7///SMG1 pseudogene 3///SMG1 p...
# 17245      SND1-IT1    SND1 intronic transcript 1 (non-protein coding)
# 17281       SNORA2A                  small nucleolar RNA, H/ACA box 2A
# 17307       SNORA55                  small nucleolar RNA, H/ACA box 55
# 17326      SNORA70B                 small nucleolar RNA, H/ACA box 70B
# 17331      SNORA70F                 small nucleolar RNA, H/ACA box 70F
# 17336      SNORA74A                 small nucleolar RNA, H/ACA box 74A
# 17466      SNORD56B                   small nucleolar RNA, C/D box 56B
# 17734         SPEF2                                  sperm flagellar 2
# 17792         SPPL3                    signal peptide peptidase like 3
# 17809        SPRR2G  small proline-rich protein 2G///small proline-...
# 18008        STARD7  StAR-related lipid transfer (START) domain con...
# 18061          STK4                          serine/threonine kinase 4
# 18186       SUV39H1  suppressor of variegation 3-9 homolog 1 (Droso...
# 18225         SYNE2     spectrin repeat containing, nuclear envelope 2
# 18266         SYTL2                               synaptotagmin-like 2
# 18305         TAF15  TAF15 RNA polymerase II, TATA box binding prot...
# 18366       TAS2R13                  taste receptor, type 2, member 13
# 18367       TAS2R14                  taste receptor, type 2, member 14
# 18370       TAS2R20                  taste receptor, type 2, member 20
# 18375        TAS2R4                   taste receptor, type 2, member 4
# 18380       TAS2R45                  taste receptor, type 2, member 45
# 18382        TAS2R5                   taste receptor, type 2, member 5
# 18383       TAS2R50                  taste receptor, type 2, member 50
# 18615        TEX261                               testis expressed 261
# 18887       TMEM115                          transmembrane protein 115
# 18992       TMEM203                          transmembrane protein 203
# 19182     TNFRSF10D  tumor necrosis factor receptor superfamily, me...
# 19264        TOMM22  translocase of outer mitochondrial membrane 22...
# 19330          TPM3                                      tropomyosin 3
# 19810         TXNIP                    thioredoxin interacting protein
# 19923        UBQLN2                                        ubiquilin 2
# 20005          ULK4                               unc-51 like kinase 4
# 20193          VAV2           vav 2 guanine nucleotide exchange factor
# 20279         VPS39  vacuolar protein sorting 39 homolog (S. cerevi...
# 20313         VTI1A  vesicle transport through interaction with t-S...
# 20569      XRCC6BP1                            XRCC6 binding protein 1
# 20637         ZBED4                 zinc finger, BED-type containing 4
# 20654        ZBTB20           zinc finger and BTB domain containing 20
# 20668        ZBTB37           zinc finger and BTB domain containing 37
# 20763          ZEB2               zinc finger E-box binding homeobox 2
# 21170        ZNF574                            zinc finger protein 574
# 21176        ZNF581                            zinc finger protein 581
# 21404         ZNRF2                             zinc and ring finger 2
#
#        mean_healthy  mean_asthma             p  p_adjusted_bh
# 18         8.176038     7.995185  2.287793e-04       0.041617
# 135        9.503262     9.249920  6.883657e-06       0.008859
# 261        5.073112     5.413564  2.536561e-04       0.043725
# 315        6.407213     6.209225  3.493704e-04       0.048863
# 431        5.591794     5.906907  5.504217e-07       0.001688
# 582        9.254869     9.035186  3.887820e-05       0.018019
# 662        3.591168     3.921505  1.794481e-04       0.039998
# 738        8.897997     9.319184  3.227949e-05       0.016113
# 777        6.779091     7.190945  2.939759e-04       0.045086
# 854        8.620867     8.342951  2.096931e-05       0.014390
# 1942       8.076010     8.262284  3.567958e-04       0.048863
# 2104       6.024939     6.300261  1.351799e-04       0.034137
